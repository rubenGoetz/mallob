# %%
import os

# ../logs_kissat
dirs = next(os.walk('../logs_kissat'))[1]
out_file = open(f"runwatch_kissat", 'w')
i = 0
for name in dirs:
    i += 1
    out_file.write(f"{i} ../kissat/build/kissat /nfs/share/instances/sat_instances/sat_instances_2023/{name}\n")
out_file.close()
    
dirs
# Out:
# ['asconhashv12_opt64_H8_M2-1yQCyA0j_m2_6.c.cnf',
#  '27_1.cnf',
#  'satcoin-genesis-UNSAT-17800.cnf',
#  'asconhashv12_opt64_H7_M2-OrF8zEw_m2_4.c.cnf',
#  'tseitin_d3_n160.cnf',
#  'WS_500_16_90_70.apx_2_DC-ST.cnf',
#  '28_2.cnf',
#  'srhd-sgi-m37-q446.25-n35-p30-s33692332.cnf',
#  'sat-bench-trig-taylor2.cnf',
#  'rovers1_ks99i.renamed-as.sat05-3971.cnf',
#  'rbsat-v760c43649gyes10.cnf',
#  'GzipFile_close_11.cnf',
#  'mchess20-mixed-45percent-blocked.cnf',
#  'SCPC-900-29.cnf',
#  'asconhashv12_opt64_H7_M2-gHvzZOd_m3_4_U11.c.cnf',
#  'g2-T99.2.0.cnf',
#  'clqcolor-08-06-07.shuffled-as.sat05-1257.cnf',
#  'cliquecoloring_n18_k7_c6.cnf',
#  'rphp_p30_r30.cnf',
#  'satcoin-genesis-UNSAT-19800.cnf',
#  'ContextModel_output_8_4_10.bul.dimacs.cnf',
#  'FileObject_open_13.cnf',
#  'asconhashv12_opt64_H6_M2-4XKSMr_m1_3_U25.c.cnf',
#  'hash_table_find_safety_size_19.cnf',
#  'collections_namedtuple_15.cnf',
#  'velev-pipe-o-uns-1.0-7.cnf',
#  'tseitin_d3_n10000.cnf',
# ...

# %%
import os
import re

dirs = next(os.walk('../logs_serial'))[1]
for file_name in dirs:
    if os.path.isfile(f"../logs_serial/{file_name}/rw"):
        os.rename(f"../logs_serial/{file_name}/rw", f"../logs_serial/{file_name}/out_file")
    
    file = open(f"../logs_serial/{file_name}/out_file")
    log = file.read()

    ben_name = re.search('/nfs/share/instances/sat_instances/sat_instances_2023/(.*)', log)
    ben_name = ben_name.groups()[0]

    if file_name != ben_name:
        os.rename(f"../logs_serial/{file_name}/", f"../logs_serial/{ben_name}/")



dirs
# Out:
# ['asconhashv12_opt64_H8_M2-1yQCyA0j_m2_6.c.cnf',
#  '27_1.cnf',
#  'satcoin-genesis-UNSAT-17800.cnf',
#  'asconhashv12_opt64_H7_M2-OrF8zEw_m2_4.c.cnf',
#  'tseitin_d3_n160.cnf',
#  'WS_500_16_90_70.apx_2_DC-ST.cnf',
#  '28_2.cnf',
#  'srhd-sgi-m37-q446.25-n35-p30-s33692332.cnf',
#  'sat-bench-trig-taylor2.cnf',
#  'rovers1_ks99i.renamed-as.sat05-3971.cnf',
#  'rbsat-v760c43649gyes10.cnf',
#  'GzipFile_close_11.cnf',
#  'mchess20-mixed-45percent-blocked.cnf',
#  'SCPC-900-29.cnf',
#  'asconhashv12_opt64_H7_M2-gHvzZOd_m3_4_U11.c.cnf',
#  'g2-T99.2.0.cnf',
#  'clqcolor-08-06-07.shuffled-as.sat05-1257.cnf',
#  'cliquecoloring_n18_k7_c6.cnf',
#  'rphp_p30_r30.cnf',
#  'satcoin-genesis-UNSAT-19800.cnf',
#  'ContextModel_output_8_4_10.bul.dimacs.cnf',
#  'FileObject_open_13.cnf',
#  'asconhashv12_opt64_H6_M2-4XKSMr_m1_3_U25.c.cnf',
#  'hash_table_find_safety_size_19.cnf',
#  'collections_namedtuple_15.cnf',
#  'velev-pipe-o-uns-1.0-7.cnf',
#  'tseitin_d3_n10000.cnf',
# ...

# %%
import re
import os

def get_runtime(log):
    runtime = 0.
    # Mallob style output
    s = re.search("RESPONSE_TIME #[0-9]+ ([0-9]+.[0-9]+)", log)
    if s:
        runtime = float(s.groups()[0])
        return runtime
    # Gimsatul style output
    s = re.search("c wall-clock-time:( )+([0-9]+.[0-9]+)", log)
    if s:
        runtime = float(s.groups()[1])
        return runtime
    # Kissat style output
    s = re.search("c process-time:( )+([0-9]+m [0-9]+s)( )+([0-9]+.[0-9]+) seconds", log)
    if s:
        runtime = float(s.groups()[3])
        return runtime
    return 0

log = open('../logs_serial/hash_table_find_safety_size_23.cnf/out_file').read()
get_runtime(log)
# Out:
# 142.2

# %%
track_2024 = [
    '002.cnf',
    '004.cnf',
    '128_100.sanitized.cnf',
    '128_125.sanitized.cnf',
    '128_75.sanitized.cnf',
    '170058440.cnf',
    '1-ET-256-K-55.sanitized.cnf',
    '1-ET-256-K-70.sanitized.cnf',
    '1-ET-512-K-110.sanitized.cnf',
    '1-ET-512-K-96.sanitized.cnf',
    '1-TC-256-K-64.sanitized.cnf',
    '1-TC-256-K-68.sanitized.cnf',
    '1-TC-256-K-71.sanitized.cnf',
    '1-ZC-1024-K-116.sanitized.cnf',
    '1-ZC-1024-K-117.sanitized.cnf',
    '1-ZC-512-K-60.sanitized.cnf',
    '1-ZC-512-K-61.sanitized.cnf',
    '1-ZC-512-K-63.sanitized.cnf',
    '1-ZC-512-K-64.sanitized.cnf',
    '1-ZC-512-K-65.sanitized.cnf',
    '1-ZC-512-K-67.sanitized.cnf',
    '2dlx_ca_bp_f_liveness.cnf',
    '32_100.sanitized.cnf',
    '32_200.sanitized.cnf',
    '32_325.sanitized.cnf',
    '32_350.sanitized.cnf',
    '64_150.sanitized.cnf',
    '64_200.sanitized.cnf',
    '64_25.sanitized.cnf',
    '6g_6color_366_050_04.cnf',
    '6s130-opt.cnf',
    '6s167-opt.cnf',
    'af-synthesis_stb_50_100_4_sat.cnf',
    'af-synthesis_stb_50_100_9_sat.cnf',
    'af-synthesis_stb_50_100_9_unsat.cnf',
    'af-synthesis_stb_50_120_4_sat.cnf',
    'af-synthesis_stb_50_140_0_unsat.cnf',
    'af-synthesis_stb_50_140_1_unsat.cnf',
    'af-synthesis_stb_50_140_3_unsat.cnf',
    'af-synthesis_stb_50_200_0_sat.cnf',
    'af-synthesis_stb_50_200_0_unsat.cnf',
    'af-synthesis_stb_50_200_4_unsat.cnf',
    'af-synthesis_stb_50_40_2_unsat.cnf',
    'af-synthesis_stb_50_40_9_sat.cnf',
    'af-synthesis_stb_50_40_9_unsat.cnf',
    'apn-sbox5-cut3-symmbreak.cnf',
    'asconhashv12_opt64_H11_M2-fCHjS2L0du5_m2_4.c.cnf',
    'asconhashv12_opt64_H11_M2-MxJOnbQIXNd_m5_6.c.cnf',
    'asconhashv12_opt64_H11_M2-tBi5i1RIgRz_m0_1_U23.c.cnf',
    'asconhashv12_opt64_H5_M2-xEJ8F_m0_3_U5.c.cnf',
    'asconhashv12_opt64_H6_M2-PgbpwX_m0_4_U1.c.cnf',
    'asconhashv12_opt64_H9_M2-MIC4kfhiA_m0_6_U2.c.cnf',
    'atco_enc1_opt1_10_15.cnf',
    'barman-pfile06-022.sas.ex.7.cnf',
    'battleship-14-26-sat.cnf',
    'benchmarks.txt',
    'bmc_QICE_snp_vld_30.cnf',
    'bphp_p23_h22.sanitized.cnf',
    'Break_08_24.xml.cnf',
    'Break_18_32.xml.cnf',
    'Break_20_72.xml.cnf',
    'Break_triple_20_36.xml.cnf',
    'Break_unsat_04_03.xml.cnf',
    'Break_unsat_06_07.xml.cnf',
    'Break_unsat_14_23.xml.cnf',
    'Break_unsat_16_27.xml.cnf',
    'Break_unsat_18_31.xml.cnf',
    'bvsub_19952.smt2.cnf',
    'circuit_32in32out_with_100gates_7in7out_dist64_seed2.sanitized.cnf',
    'circuit_32in32out_with_350gates_6in6out_dist64_seed1.sanitized.cnf',
    'circuit_32in32out_with_400gates_6in6out_dist64_seed1.sanitized.cnf',
    'circuit_32in32out_with_500gates_6in6out_dist64_seed1.sanitized.cnf',
    'circuit_32in32out_with_64gates_8in6out_dist128_seed2.sanitized.cnf',
    'circuit_32in32out_with_70gates_7in7out_dist128_seed1.sanitized.cnf',
    'circuit_32in32out_with_80gates_7in7out_dist128_seed1.sanitized.cnf',
    'circuit_32in32out_with_96gates_7in7out_dist128_seed1.sanitized.cnf',
    'circuit_32in64out_with_150gates_6in6out_dist256_seed1.sanitized.cnf',
    'circuit_48in24out_with_100gates_7in7out_dist128_seed1.sanitized.cnf',
    'circuit_48in64out_with_1000gates_4in4out_dist128_seed4.sanitized.cnf',
    'circuit_48in64out_with_700gates_4in4out_dist128_seed1.sanitized.cnf',
    'circuit_48in64out_with_800gates_4in4out_dist128_seed1.sanitized.cnf',
    'circuit_48in64out_with_800gates_4in4out_dist128_seed4.sanitized.cnf',
    'circuit_64in64out_with_64gates_8in5out_dist256_seed1.sanitized.cnf',
    'Circuit_multiplier22.cnf',
    'cliquecolouring_n13_k8_c7.sanitized.cnf',
    'cliquecolouring_n13_k9_c8.sanitized.cnf',
    'cliquecolouring_n15_k9_c8.sanitized.cnf',
    'cliquecolouring_n21_k6_c5.sanitized.cnf',
    'cliquecolouring_n31_k5_c4.sanitized.cnf',
    'cliquecolouring_n41_k5_c4.sanitized.cnf',
    'clique_n2_k10.sanitized.cnf',
    'combined-crypto1-wff-seed-102-wffvars-500-cryptocplx-31-overlap-2.cnf',
    'combined-crypto1-wff-seed-1-wffvars-450-cryptocplx-40-overlap-2.cnf',
    'constraints_16_0.3_1.sanitized.cnf',
    'constraints_16_0.4_1.sanitized.cnf',
    'constraints_16_0.5_1.sanitized.cnf',
    'constraints_17_0.3_2.sanitized.cnf',
    'constraints_17_0.4_1.sanitized.cnf',
    'constraints_17_0.4_2.sanitized.cnf',
    'constraints_17_0.5_2.sanitized.cnf',
    'constraints_18_0.3_2.sanitized.cnf',
    'constraints_18_0.4_2.sanitized.cnf',
    'constraints_18_0.5_2.sanitized.cnf',
    'constraints_25_4_5_12_12_0_0_0.sanitized.cnf',
    'crafted_n12_d6_c4_num23.cnf',
    'crn_11_99_u.cnf',
    'ctl_4201_555_unsat_pre.cnf',
    'ctl_4291_567_2_unsat-sc2013.cnf',
    'ctl_4291_567_9_unsat.cnf',
    'DLTM_twitter774_83_17.cnf',
    'Dodecahedron-k7.cnf',
    'ecarev-110-4099-22-30-7.cnf',
    'EDP3-11000.cnf',
    'ER_400_20_4.apx_1_DC-AD.cnf',
    'ER_400_20_4.apx_2_DC-AD.cnf',
    'ER_400_20_4.apx_2_DC-ST.cnf',
    'ER_400_20_7.apx_1_DC-AD.cnf',
    'ER_400_20_7.apx_2_DC-AD.cnf',
    'ER_400_20_7.apx_2_DC-ST.cnf',
    'ER_500_30_3.apx_1_DC-ST.cnf',
    'ER_500_30_3.apx_2_DC-AD.cnf',
    'ex065_25.cnf',
    'exam_flat_0.04_2018_3.cnf',
    'f9idw.cnf',
    'fermat-931960058139995587.cnf',
    'fixedbandwidth-eq-31_shuffled.cnf',
    'FmlaEquivChain_4_6_6.sanitized.cnf',
    'FmlaEquivChain_4_8_8.sanitized.cnf',
    'FmlaImplyChain_3_7_7.sanitized.cnf',
    'FmlaImplyChain_3_7_8.sanitized.cnf',
    'Folkman-175-1251868.sanitized.cnf',
    'Folkman-175-7416734.sanitized.cnf',
    'Folkman-175-9054056.sanitized.cnf',
    'Folkman-180-11710376.sanitized.cnf',
    'Folkman-180-5383714.sanitized.cnf',
    'Folkman-185-152478531.sanitized.cnf',
    'Folkman-185-19924337.sanitized.cnf',
    'Folkman-185-75415683.sanitized.cnf',
    'Folkman-190-104806020.sanitized.cnf',
    'Folkman-190-358004741.sanitized.cnf',
    'Folkman-190-66337703.sanitized.cnf',
    'frb45-21-2.used-as.sat04-884.cnf',
    'frb65-12-2.used-as.sat04-874.cnf',
    'g2-ak128boothbg2msaig.cnf',
    'g2-ak128boothbg2msisc.cnf',
    'g2-hwmcc15deep-6s161-k17.cnf',
    'g2-hwmcc15deep-bob12s02-k16.cnf',
    'g2-slp-synthesis-aes-top30.cnf',
    'g2-T93.2.1.cnf',
    'g2-test_v5_r10_vr10_c1_s21502.smt2-cvc4.cnf',
    'goldcrest-and-9.cnf',
    'GracefulGraph-K05-P02_c18.cnf',
    'grs-64-128.cnf',
    'grs-64-64.cnf',
    'HCP-446-105.cnf',
    'hcp_CP18_18.cnf',
    'hwb-n24-02-S786928571.shuffled-as.sat03-1618.cnf',
    'hwmcc12miters-xits-iso-6s111.sanitized.cnf',
    'hwmcc17miters-xits-iso-6s281b35.sanitized.cnf',
    'hwmcc17miters-xits-iso-bobsmfpu.sanitized.cnf',
    'hwmcc17miters-xits-iso-oski15a08b00s.sanitized.cnf',
    'hwmcc17miters-xits-iso-oski15a08b08s.sanitized.cnf',
    'hwmcc20miters-iso-mul2.sanitized.cnf',
    'hwmcc20miters-iso-mul3.sanitized.cnf',
    'hwmcc20miters-iso-mul7.sanitized.cnf',
    'hwmcc20miters-iso-rast-p06.sanitized.cnf',
    'hwmcc20miters-iso-rast-p11.sanitized.cnf',
    'IBM_FV_2004_rule_batch_1_31_1_SAT_dat.k40.debugged.cnf',
    'ITC2021_Early_10.xml.cnf',
    'ITC2021_Early_3.xml.cnf',
    'ITC2021_Middle_1.xml.cnf',
    'j3037_10_mdd_b.cnf',
    'j3037_10_mdd_bm1.cnf',
    'j3037_10_rggt_b.cnf',
    'j3037_1_gmto_b.cnf',
    'j3037_1_mdd_b.cnf',
    'j3037_9_mdd_bm1.cnf',
    'j3037_9_rggt_b.cnf',
    'j3045_10_gmto_b.cnf',
    'j3045_10_rggt_b.cnf',
    'j3045_4_gmto_b.cnf',
    'j3045_4_mdd_bm1.cnf',
    'jgiraldezlevy.2200.9086.08.40.41.cnf',
    'Kakuro-easy-097-ext.xml.hg_4.cnf',
    'lec_mult_CvD_11x11.sanitized.cnf',
    'lec_mult_CvK_11x10.sanitized.cnf',
    'lec_mult_CvK_11x11.sanitized.cnf',
    'lec_mult_CvK_12x11.sanitized.cnf',
    'lec_mult_CvK_12x12.sanitized.cnf',
    'lec_mult_CvW_12x11.sanitized.cnf',
    'lec_mult_CvW_12x12.sanitized.cnf',
    'lec_mult_DvK_11x10.sanitized.cnf',
    'lec_mult_DvK_12x12.sanitized.cnf',
    'lec_mult_DvW_11x10.sanitized.cnf',
    'lec_mult_DvW_12x11.sanitized.cnf',
    'lec_mult_DvW_12x12.sanitized.cnf',
    'lec_mult_KvW_10x10.sanitized.cnf',
    'lec_mult_KvW_11x10.sanitized.cnf',
    'lec_mult_KvW_12x11.sanitized.cnf',
    'linked_list_swap_contents_safety_unwind45.cnf',
    'linked_list_swap_contents_safety_unwind54.cnf',
    'linked_list_swap_contents_safety_unwind57.cnf',
    'linked_list_swap_contents_safety_unwind62.cnf',
    'linked_list_swap_contents_safety_unwind63.cnf',
    'linked_list_swap_contents_safety_unwind65.cnf',
    'linked_list_swap_contents_safety_unwind68.cnf',
    'linked_list_swap_contents_safety_unwind69.cnf',
    'linked_list_swap_contents_safety_unwind70.cnf',
    'linked_list_swap_contents_safety_unwind73.cnf',
    'linked_list_swap_contents_safety_unwind76.cnf',
    'linked_list_swap_contents_safety_unwind78.cnf',
    'linked_list_swap_contents_safety_unwind80.cnf',
    'lru_10.sanitized.cnf',
    'lru_6.sanitized.cnf',
    'lru_7.sanitized.cnf',
    'lru_8.sanitized.cnf',
    'lru_9.sanitized.cnf',
    'manol-pipe-g10bid_i.cnf',
    'marg5x5.shuffled-as.sat03-1455.cnf',
    'MASG0_72_keystream76_0.cnf',
    'mchess_15.cnf',
    'mchess_16.cnf',
    'mchess_17.cnf',
    'md5_48_1.cnf',
    'mdp-28-10-unsat.cnf',
    'mdp-28-11-sat.cnf',
    'mdp-28-14-sat.cnf',
    'mdp-28-14-unsat.cnf',
    'mdp-28-16-unsat.cnf',
    'mdp-32-10-sat.cnf',
    'mdp-32-10-unsat.cnf',
    'mdp-32-11-sat.cnf',
    'mdp-32-11-unsat.cnf',
    'mdp-32-12-unsat.cnf',
    'mdp-32-14-sat.cnf',
    'mdp-32-14-unsat.cnf',
    'mdp-32-16-sat.cnf',
    'mdp-36-10-sat.cnf',
    'mdp-36-10-unsat.cnf',
    'mdp-36-12-unsat.cnf',
    'mdp-36-14-sat.cnf',
    'mp1-blockpuzzle_5x10_s7_free4.cnf',
    'mp1-klieber2017s-0500-023-t12.cnf',
    'mp1-Nb5T15.cnf',
    'mp1-Nb7T42.cnf',
    'mp1-ps_5000_21250_3_0_0.8_0_1.50_6.cnf',
    'mrpp_4x4#12_12.cnf',
    'mulhs016-sc2009.cnf',
    'Nb13T165.cnf',
    'Nb44T6.cnf',
    'noL-11-0.sanitized.cnf',
    'noL-11-10.sanitized.cnf',
    'noL-11-12.sanitized.cnf',
    'noL-11-14.sanitized.cnf',
    'noL-11-16.sanitized.cnf',
    'noL-11-18.sanitized.cnf',
    'noL-11-20.sanitized.cnf',
    'noL-11-2.sanitized.cnf',
    'noL-11-4.sanitized.cnf',
    'noL-11-6.sanitized.cnf',
    'noL-11-8.sanitized.cnf',
    'oisc-subrv-sll-nested-11.cnf',
    'oisc-subrv-sll-nested-13.cnf',
    'openstacks-sequencedstrips-nonadl-nonnegated-os-sequencedstrips-p30_3.025-NOTKNOWN.cnf',
    'or_randxor_k3_n510_m510.sanitized.cnf',
    'pb_300_05_lb_17.cnf',
    'pb_300_09_lb_07.cnf',
    'pcmax-scheduling-m11-1517-6802-UNSAT.sanitized.cnf',
    'pcmax-scheduling-m12-8049-55035-SAT.sanitized.cnf',
    'pcmax-scheduling-m13-1655-9604-UNSAT.sanitized.cnf',
    'pcmax-scheduling-m13-2011-12813-UNSAT.sanitized.cnf',
    'pcmax-scheduling-m15-2352-13561-SAT.sanitized.cnf',
    'pcmax-scheduling-m19-10199-62102-UNSAT.sanitized.cnf',
    'pcmax-scheduling-m19-2974-16501-UNSAT.sanitized.cnf',
    'pcmax-scheduling-m24-17855-226744-SAT.sanitized.cnf',
    'pcmax-scheduling-m24-24102-255206-SAT.sanitized.cnf',
    'pcmax-scheduling-m26-6398-62377-UNSAT.sanitized.cnf',
    'pcmax-scheduling-m30-14113-167638-UNSAT.sanitized.cnf',
    'pcmax-scheduling-m35-32274-371389-SAT.sanitized.cnf',
    'pcmax-scheduling-m37-28831-324346-SAT.sanitized.cnf',
    'pcmax-scheduling-m40-26287-324155-SAT.sanitized.cnf',
    'pcmax-scheduling-m43-38782-385402-SAT.sanitized.cnf',
    'post-cbmc-aes-ee-r3-noholes.cnf',
    'preimage_80r_495m_160h_seed_379.cnf',
    'Ptn-7824-b18.cnf',
    'qwh.50.1250.shuffled-as.sat03-1655.cnf',
    'qwh.60.1728.shuffled-as.sat03-1659.cnf',
    'rbsat-v1150c84314gyes1.cnf',
    'rbsat-v760c43649gyes3.cnf',
    'rbsat-v760c43649gyes7.cnf',
    'rbsat-v760c43649gyes9.cnf',
    'rbsat-v945c61409gyes9-sc2009.cnf',
    'REGRandom-K3-L3-Seed25.sanitized.cnf',
    'REGRandom-K4-L1-Seed30.sanitized.cnf',
    'REGRandom-K4-L2-Seed35.sanitized.cnf',
    'REGRandom-K4-L3-Seed40.sanitized.cnf',
    'rook-42-0-1.cnf',
    'rook-56-0-0.cnf',
    'rook-56-1-1.cnf',
    'rphp_p8_r160.sanitized.cnf',
    'rphp_p8_r170.sanitized.cnf',
    'Schur_161_5_d38.cnf',
    'sgen1-sat-180-100.cnf',
    'sgen1-unsat-121-100.cnf',
    'SGI_30_60_19_60_6-dir.shuffled-as.sat03-112.cnf',
    'SGI_30_80_26_70_4-log.shuffled-as.sat03-208.cnf',
    'shuffling-2-s25242449-of-bench-sat04-727.used-as.sat04-753.cnf',
    'si2-b03m-m800-03.cnf',
    'simon-r16-1.sanitized.cnf',
    'simon-r17-0.sanitized.cnf',
    'simon-r18-0.sanitized.cnf',
    'simon-r19-1.sanitized.cnf',
    'simon-r20-0.sanitized.cnf',
    'simon-r21-0.sanitized.cnf',
    'simon-r22-1.sanitized.cnf',
    'simon-r23-1.sanitized.cnf',
    'simon-r24-1.sanitized.cnf',
    'simon-r25-0.sanitized.cnf',
    'sokoban-p16.sas.ex.15-sc2016.cnf',
    'sokoban-p20.sas.cr.25.cnf',
    'sokoban-p20.sas.cr.33.cnf',
    'spg_200_316.cnf',
    'srhd-sgi-m37-q446.25-n35-p30-s33692332.cnf',
    'stable-300-0.1-20-98765432130020.cnf',
    'stb_418_125.apx_1_DC-AD.cnf',
    'stb_418_125.apx_1_DC-ST.cnf',
    'stb_418_125.apx_2_DC-AD.cnf',
    'stb_495_168.apx_1_DC-AD.cnf',
    'stb_495_168.apx_2_DC-AD.cnf',
    'stb_531_83.apx_1_DC-ST.cnf',
    'stb_531_83.apx_2_DC-ST.cnf',
    'stb_588_138.apx_1_DC-AD.cnf',
    'stb_588_138.apx_1_DC-ST.cnf',
    'StConn_7_128.sanitized.cnf',
    'StConn_8_32.sanitized.cnf',
    'sted5_0x1e3-20.cnf',
    'sted5_0x24204-50.cnf',
    'string_compare_safety_cbmc_unwinding_900.cnf',
    'summle_X11112_steps6_I1-2-2-4-4-8-25-100.cnf',
    'summle_X4044_steps7_I1-2-2-4-4-8-25-100.cnf',
    'summle_X4053_steps8_I1-2-2-4-4-8-25-100.cnf',
    'T105.2.0.cnf',
    'test_v7_r17_vr5_c1_s25451.smt2-cvc4.cnf',
    'Timetable_C_392_E_62_Cl_26_S_28.cnf',
    'tseitin_d3_n158.sanitized.cnf',
    'tseitin_d3_n162.sanitized.cnf',
    'tseitin_d3_n174.sanitized.cnf',
    'tseitingrid6x200_shuffled.cnf',
    'tseitin_grid_n11_m20.sanitized.cnf',
    'two-trees-1023v.sanitized.cnf',
    'two-trees-511v.sanitized.cnf',
    'urq45.cnf',
    'urqh1c5x5.shuffled-as.sat03-1468.cnf.mis-103.debugged.cnf',
    'VanDerWaerden_2-3-14_186.cnf',
    'worker_20_40_20_0.95.cnf',
    'worker_30_60_25_0.9.cnf',
    'worker_40_80_40_0.9.cnf',
    'worker_550_550_550_0.3.cnf',
    'WS_500_16_70_10.apx_1_DC-ST.cnf',
    'WS_500_16_70_10.apx_2_DC-AD.cnf',
    'WS_500_16_90_70.apx_2_DC-AD.cnf',
    'x9-08014.sat.sanitized.cnf',
    'x9-08075.sat.sanitized.cnf',
    'x9-09004.sat.sanitized.cnf',
    'x9-09007.sat.sanitized.cnf',
    'x9-09014.sat.sanitized.cnf',
    'x9-09024.sat.sanitized.cnf',
    'x9-09047.sat.sanitized.cnf',
    'x9-09051.sat.sanitized.cnf',
    'x9-09054.sat.sanitized.cnf',
    'x9-09057.sat.sanitized.cnf',
    'x9-09076.sat.sanitized.cnf',
    'x9-09098.sat.sanitized.cnf',
    'x9-10002.sat.sanitized.cnf',
    'x9-10007.sat.sanitized.cnf',
    'x9-10014.sat.sanitized.cnf',
    'x9-10027.sat.sanitized.cnf',
    'x9-10031.sat.sanitized.cnf',
    'x9-10038.sat.sanitized.cnf',
    'x9-10051.sat.sanitized.cnf',
    'x9-10076.sat.sanitized.cnf',
    'x9-10083.sat.sanitized.cnf',
    'x9-10084.sat.sanitized.cnf',
    'x9-10093.sat.sanitized.cnf',
    'x9-10096.sat.sanitized.cnf',
    'x9-10098.sat.sanitized.cnf',
    'x9-11034.sat.sanitized.cnf',
    'x9-11053.sat.sanitized.cnf',
    'x9-11062.sat.sanitized.cnf',
    'x9-11077.sat.sanitized.cnf',
    'x9-11088.sat.sanitized.cnf',
    'x9-11093.sat.sanitized.cnf',
    'x9-11094.sat.sanitized.cnf',
    'x9-12001.sat.sanitized.cnf',
    'x9-12014.sat.sanitized.cnf',
    'x9-12021.sat.sanitized.cnf',
    'x9-12035.sat.sanitized.cnf',
    'x9-12063.sat.sanitized.cnf',
    'x9-12087.sat.sanitized.cnf',
    'x9-12092.sat.sanitized.cnf',
    'x9-12098.sat.sanitized.cnf',
]

track_2024_path = '/hppfs/work/pn72pu/di97xah/track_2024'

file = open('../../runwatch/runwatch_kissat_sMUC', 'w')
for i, instance in enumerate(track_2024):
    file.write(f"{i + 1} ../kissat/build/kissat {track_2024_path}/{instance}\n")
file.close()
